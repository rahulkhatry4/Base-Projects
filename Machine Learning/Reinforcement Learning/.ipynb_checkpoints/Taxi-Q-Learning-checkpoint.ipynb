# %%
import gym
import baselines
import numpy as np
import random
import pickle

# %% [markdown]
# # Make the Environment

# %%
env = gym.make('Taxi-v2')
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %% [markdown]
# # Create the Q Matrix

# %%
action_size = env.action_space.n
state_size = env.observation_space.n
q_matrix_size = (state_size,action_size)

# %%
qtable = np.zeros(q_matrix_size)

# %% [markdown]
# # Set Hyper-Parameters

# %%
total_episodes = 50000
total_test_episodes = 100
max_steps = 99

learning_rate = 0.7
gamma = 0.618

epsilon = 1.0
max_epsilon = 1.0
min_epsilon = 0.01
decay_rate = 0.01

# %% [markdown]
# # Learn the Q-Matrix
# If this Process was substituted by learning the Q-Matrix (Or the Q-Function) using a deep neural network then it would be called deep-Q Learning

# %%
for episode in range(total_episodes):
    state = env.reset()
    step = 0
    done = False
    
    for step in range(max_steps):
        exp_exp_tradeoff = random.uniform(0,1)
        
        if exp_exp_tradeoff > epsilon:
            action = np.argmax(qtable[state,:])
            
        else:
            action = env.action_space.sample()
            
        new_state, reward, done, info = env.step(action)
        
        qtable[state, action] = qtable[state, action] + learning_rate*(reward + gamma*np.max(qtable[new_state, :]) - qtable[state, action])
        
        state = new_state
        
        if done == True:
            break
            
    episode += 1
    
    epsilon = min_epsilon + (max_epsilon - min_epsilon)*np.exp(-decay_rate*episode)

# %% [markdown]
# # Save Checkpoint

# %%
pickle.dump(qtable, open("taxi_qtable.p", "wb"))

# %%
qtable = pickle.load(open("taxi_qtable.p", "rb"))

# %%
qtable
# Out:
# array([[  0.        ,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ -1.89494505,  -1.44813154,  -1.89827954,  -1.45017011,
#          -0.72512948, -10.44858787],
#        [ -0.72513952,   0.444719  ,  -0.72920948,   0.44471911,
#           2.33782249,  -8.5552258 ],
#        ...,
#        [  2.27945344,   5.40100727,   2.33091436,   0.44375222,
#          -6.66395468,  -6.66217896],
#        [ -2.32131447,  -1.44832488,  -2.35963957,  -2.35767684,
#         -10.96198096, -10.03282   ],
#        [ 12.38685697,  -1.30039   ,  -1.457512  ,  31.35602094,
#           4.45851645,   5.33530003]])

# %% [markdown]
# # Render Results

# %%
env.reset()
rewards = []
for episode in range(total_test_episodes):
    state = env.reset()
    step = 0
    done = False
    total_rewards = 0
    print('*****************')
    print('Episode ', episode)
    
    for step in range(max_steps):
        env.render()
        action = np.argmax(qtable[state,:])
        new_state, reward, done, info = env.step(action)
        
        total_rewards += reward
        
        if done:
            rewards.append(total_rewards)
            print("Score", total_rewards)
            break
        state = new_state
        
env.close()
print('Avg Score : ' + str(sum(rewards)/total_test_episodes))
# Out:
# *****************
# Episode  0
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# +---------+
# |R: | : :G|
# |_: : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : : : : |
# |_: : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : : : : |
# | :_: : : |
# | | : | : |
# |Y| : |B: |
# +---------+
# ...
